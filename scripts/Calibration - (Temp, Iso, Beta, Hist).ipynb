# %% [markdown]
# # Calibration

# %% [markdown]
# Testing calibration method on neural networks on image data.

# %%
from sklearn.metrics import log_loss, brier_score_loss
from keras.losses import categorical_crossentropy
from scipy.optimize import minimize 
import numpy as np
from utility.unpickle_probs import unpickle_probs
from utility.calibration import ECE, MCE
from os.path import join
import sklearn.metrics as metrics
import pandas as pd
from betacal import BetaCalibration
from sklearn.isotonic import IsotonicRegression
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load in Data

# %% [markdown]
# Some data for testing methods.

# %%
PATH = join('..', '..', 'Semester IV', 'NN_image_probs')
files = ('probs_resnet110_c10_logits.p', 'probs_resnet110_c100_logits.p', )

FILE_PATH = join(PATH, files[0])
#(y_probs_val, y_val), (y_probs_test, y_test) = unpickle_probs(FILE_PATH, True)
(y_logits_val, y_val), (y_logits_test, y_test) = unpickle_probs(FILE_PATH, True)
# Out:
# y_probs_val: (5000, 10)
# y_true_val: (5000, 1)
# y_probs_test: (10000, 10)
# y_true_test: (10000, 1)

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=1, keepdims=1)

# %% [markdown]
# ### Check out the Negative Log Likelihood (NLL).

# %%
y_probs_val = softmax(y_logits_val)
y_probs_test = softmax(y_logits_test)

# %%
y_probs_val
# Out:
# array([[  3.50495610e-09,   1.19858523e-09,   9.99999762e-01, ...,
#           3.58365365e-10,   1.65589658e-08,   5.31787308e-08],
#        [  1.00000000e+00,   3.42834561e-09,   1.12174181e-09, ...,
#           3.91965106e-12,   5.52859358e-09,   1.04786575e-10],
#        [  7.83461230e-12,   5.50028426e-11,   1.36148398e-10, ...,
#           6.90314739e-09,   1.84315185e-11,   5.23301680e-10],
#        ...,
#        [  9.51968539e-13,   1.73751768e-12,   4.28410606e-12, ...,
#           1.00000000e+00,   4.82873968e-14,   4.22664204e-12],
#        [  3.68825553e-10,   1.33624167e-09,   9.49588463e-11, ...,
#           1.00000000e+00,   1.06427133e-11,   6.58591723e-11],
#        [  2.29454624e-08,   3.61428859e-10,   2.38165171e-06, ...,
#           2.24385076e-06,   4.55320764e-12,   2.68068068e-10]], dtype=float32)

# %%
log_loss(y_true=y_val, y_pred=y_probs_val)
# Out:
# 0.30016390198023241

# %%
log_loss(y_true=y_test, y_pred=y_probs_test)
# Out:
# 0.35827413497065691

# %% [markdown]
# The NLL is different from the actual output for some reason. Look more into it.

# %% [markdown]
# ## Temperature Scaling

# %%
def temp_scale(y_probs, x):
    return y_probs/x

# %%
def loss_fun(x, y_probs, y_true):
    scaled_probs = softmax(temp_scale(y_probs, x))    
    loss = log_loss(y_true=y_true, y_pred=scaled_probs)
    
    return loss

# %%
def evaluate(y_probs, y_true, verbose = False, normalize = False, bins = 15):
    
    y_preds = np.argmax(y_probs, axis=1)  # Take maximum confidence as prediction
    
    if normalize:
        y_confs = np.max(y_probs, axis=1)/np.sum(y_probs, axis=1)
        # Check if everything below or equal to 1?
    else:
        y_confs = np.max(y_probs, axis=1)  # Take only maximum confidence
    
    accuracy = metrics.accuracy_score(y_true, y_preds) * 100
    error = 100 - accuracy
    
        # Calculate ECE
    ece = ECE(y_confs, y_preds, y_true, bin_size = 1/bins)
    # Calculate MCE
    mce = MCE(y_confs, y_preds, y_true, bin_size = 1/bins)
    
    loss = log_loss(y_true=y_true, y_pred=y_probs)
    
    y_prob_true = np.array([y_probs[i, idx] for i, idx in enumerate(y_true)])  # Probability of positive class
    brier = brier_score_loss(y_true=y_true, y_prob=y_prob_true)  # Brier Score (MSE)
    
    if verbose:
        print("Accuracy:", accuracy)
        print("Error:", error)
        print("ECE:", ece)
        print("MCE:", mce)
        print("Loss:", loss)
        print("brier:", brier)
    
    return (error, ece, mce, loss, brier)

# %%
evaluate(softmax(y_logits_test), y_test, verbose=True)
# Out:
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
# (6.4399999999999977,
#  0.047503518640995043,
#  0.29579895734786987,
#  0.35827413497065691,
#  0.83157410273384924)

# %%
evaluate(softmax(temp_scale(y_logits_test, 2.395011)), y_test, verbose=True)
# Out:
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.011320804061
# MCE: 0.236392512918
# Loss: 0.20926125583
# brier: 0.788059206672
# (6.4399999999999977,
#  0.011320804060995518,
#  0.23639251291751862,
#  0.20926125582950877,
#  0.78805920667178175)

# %%
PATH = join('..', '..', 'Semester IV', 'NN_image_probs')
files = ('probs_resnet110_c10_logits.p', 'probs_resnet110_c100_logits.p', 
         'probs_densenet40_c10_logits.p', 'probs_densenet40_c100_logits.p',
        'probs_resnet_wide32_c10_logits.p', 'probs_resnet_wide32_c100_logits.p',
        'probs_resnet152_imgnet_logits.p', 'probs_densenet161_imgnet_logits.p')

def temp_results(path, files, method = "BFGS"):
    
    df = pd.DataFrame(columns=["Name", "Error", "ECE", "MCE", "Loss", "Brier", "Temperature"])
    
    
    for i, f in enumerate(files):
        
        name = "_".join(f.split("_")[1:-1])
        print(name)

        FILE_PATH = join(path, f)
        (y_logits_val, y_val), (y_logits_test, y_test) = unpickle_probs(FILE_PATH)
        
        opt = minimize(loss_fun, x0 = 1, args=(y_logits_val, y_val), options={'maxiter':200}, method = method)
        temp = opt.x[0]
        
        _, _, _, _, _ = evaluate(softmax(temp_scale(y_logits_val, temp)), y_val, verbose=True)
        error, ece, mce, loss, brier = evaluate(softmax(y_logits_test), y_test, verbose=False)  # Test before scaling
        error2, ece2, mce2, loss2, brier2 = evaluate(softmax(temp_scale(y_logits_test, temp)), y_test, verbose=False)
        
        df.loc[i*2] = [name, error, ece, mce, loss, brier, temp]
        df.loc[i*2+1] = [(name + "_temp"), error2, ece2, mce2, loss2, brier2, temp]

        
    return df

# %%
df_temp_scale = temp_results(PATH, files)
# Out:
# resnet110_c10
# Accuracy: 94.62
# Error: 5.38
# ECE: 0.00728217680454
# MCE: 0.816615432501
# Loss: 0.180503754565
# brier: 0.799735165234
# resnet110_c100
# Accuracy: 72.1
# Error: 27.9
# ECE: 0.0208565565631
# MCE: 0.056080172789
# Loss: 1.0636127493
# brier: 0.531455581933
# densenet40_c10
# Accuracy: 93.82
# Error: 6.18
# ECE: 0.00594705242515
# MCE: 0.10719075799
# Loss: 0.186612238607
# brier: 0.783365853767
# densenet40_c100
# Accuracy: 70.26
# Error: 29.74
# ECE: 0.0144420869678
# MCE: 0.045564418529
# Loss: 1.0773751477
# brier: 0.493179245312
# resnet_wide32_c10
# Accuracy: 96.02
# Error: 3.98
# ECE: 0.00712747764289
# MCE: 0.242319499453
# Loss: 0.134110293426
# brier: 0.826368418946
# resnet_wide32_c100
# Accuracy: 78.46
# Error: 21.54
# ECE: 0.0407689332046
# MCE: 0.156267919276
# Loss: 0.836059538963
# brier: 0.641082268727
# resnet152_imgnet
# Accuracy: 75.36
# Error: 24.64
# ECE: 0.0245080424418
# MCE: 0.0559367342452
# Loss: 1.00401962933
# brier: 0.574710464688
# densenet161_imgnet
# Accuracy: 77.26
# Error: 22.74
# ECE: 0.0208654103999
# MCE: 0.0781966217362
# Loss: 0.909294445006
# brier: 0.602978049851

# %%
df_temp_scale
# Out:
#                        Name   Error       ECE       MCE      Loss     Brier  \
# 0             resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_temp   6.440  0.011321  0.236393  0.209261  0.788059
# 2            resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_temp  28.520  0.023797  0.070991  1.091691  0.524876
# 4            densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_temp   7.580  0.009464  0.099293  0.225086  0.770248
# 6           densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_temp  30.000  0.009021  0.022128  1.057131  0.491403
# 8         resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_temp   5.010  0.007963  0.254111  0.154391  0.814687
# 10       resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_temp  22.800  0.042269  0.108004  0.871434  0.632460
# 12         resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_temp  25.292  0.022217  0.060533  1.016867  0.571829
# 14       densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_temp  23.400  0.020913  0.050933  0.926957  0.599938
#
#     Temperature
# 0      2.395011
# 1      2.395011
# 2      2.310216
# 3      2.310216
# 4      2.882550
# 5      2.882550
# 6      3.194026
# 7      3.194026
# 8      1.518296
# 9      1.518296
# 10     1.290157
# 11     1.290157
# 12     1.251008
# 13     1.251008
# 14     1.214433
# 15     1.214433

# %% [markdown]
# ## Extension of Binning Methods

# %% [markdown]
# ## Isotonic  Regression

# %%
from sklearn.linear_model import LogisticRegression
from calmap import plot_calibration_map
from matplotlib import pyplot as plt

# %%
PATH = join('..', '..', 'Semester IV', 'NN_image_probs')
files = ('probs_resnet110_c10_logits.p', 'probs_resnet110_c100_logits.p', 
         'probs_densenet40_c10_logits.p', 'probs_densenet40_c100_logits.p',
        'probs_resnet_wide32_c10_logits.p', 'probs_resnet_wide32_c100_logits.p',
        'probs_resnet152_imgnet_logits.p', 'probs_densenet161_imgnet_logits.p')

# Calibration results for one-vs-all method
def cal_results(method, path, files, m_kwargs = {}, check_val = False):
    
    df = pd.DataFrame(columns=["Name", "Error", "ECE", "MCE", "Loss", "Brier"])
    
    for i, f in enumerate(files):
        
        name = "_".join(f.split("_")[1:-1])
        print("\n", name)

        FILE_PATH = join(path, f)
        (y_logits_val, y_val), (y_logits_test, y_test) = unpickle_probs(FILE_PATH)

        y_probs_val = softmax(y_logits_val)  # Softmax logits
        y_probs_test = softmax(y_logits_test)
        K = y_probs_test.shape[1]

        # Go through all the classes
        for k in range(K):
            # Prep class labels (1 fixed true class, 0 other classes)
            y_cal = np.array(y_val == k, dtype="int")[:, 0]

            # Train model
            model = method(**m_kwargs)
            model.fit(y_probs_val[:, k], y_cal) # Get only one column with probs for given class "k"

            y_probs_val[:, k] = model.predict(y_probs_val[:, k])  # Predict new values based on the fittting
            y_probs_test[:, k] = model.predict(y_probs_test[:, k])

            # Replace NaN with 0, as it should be close to zero  # TODO is it needed?
            idx_nan = np.where(np.isnan(y_probs_test))
            y_probs_test[idx_nan] = 0
            
            idx_nan = np.where(np.isnan(y_probs_val))
            y_probs_val[idx_nan] = 0

        if check_val:  # Check results on validation set
            _, _, _, _, _ = evaluate(softmax(y_logits_val), y_val, verbose=True, normalize=False)  #
            _, _, _, _, _ = evaluate(y_probs_val, y_val, verbose=True, normalize=True)
            
        # Get results for test set
        error, ece, mce, loss, brier = evaluate(softmax(y_logits_test), y_test, verbose=True, normalize=False)
        error2, ece2, mce2, loss2, brier2 = evaluate(y_probs_test, y_test, verbose=False, normalize=True)

        # Add results into DataFrame
        df.loc[i*2] = [name, error, ece, mce, loss, brier]
        df.loc[i*2+1] = [(name + "_calib"), error2, ece2, mce2, loss2, brier2]

        
    return df

# %%
params = {'y_min':0, 'y_max':1}
df_iso = cal_results(IsotonicRegression, PATH, files, params)
# Out:
#  resnet110_c10
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
#
#  resnet110_c100
# Accuracy: 71.48
# Error: 28.52
# ECE: 0.184804543945
# MCE: 0.398817125148
# Loss: 1.69371210955
# brier: 0.661139586803
# C:\Users\Markus\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\Markus\Documents\NN_calibration\scripts\utility\calibration.py:118: RuntimeWarning: invalid value encountered in greater
#   filtered_tuples = [x for x in zip(pred, true, conf) if x[2] > conf_thresh_lower and x[2] <= conf_thresh_upper]
#  densenet40_c10
# Accuracy: 92.42
# Error: 7.58
# ECE: 0.055002704373
# MCE: 0.333955179269
# Loss: 0.42820705658
# brier: 0.819165176082
#
#  densenet40_c100
# Accuracy: 70.0
# Error: 30.0
# ECE: 0.211562852757
# MCE: 0.45400331452
# Loss: 2.0173981798
# brier: 0.655000941434
#
#  resnet_wide32_c10
# Accuracy: 94.99
# Error: 5.01
# ECE: 0.0262912020743
# MCE: 0.270675277616
# Loss: 0.18078037455
# brier: 0.837849477046
#
#  resnet_wide32_c100
# Accuracy: 77.2
# Error: 22.8
# ECE: 0.0824934380092
# MCE: 0.205758135969
# Loss: 0.924750990686
# brier: 0.679727633367
#
#  resnet152_imgnet
# Accuracy: 74.708
# Error: 25.292
# ECE: 0.0665072336364
# MCE: 0.133044166026
# Loss: 1.06397533857
# brier: 0.624490802257
#
#  densenet161_imgnet
# Accuracy: 76.6
# Error: 23.4
# ECE: 0.0589743148203
# MCE: 0.138486335666
# Loss: 0.962239300614
# brier: 0.645603191194

# %%
df_iso
# Out:
#                       Name   Error       ECE       MCE      Loss     Brier
# 0            resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_iso   6.360  0.014736  0.245814  0.270758  0.790379
# 2           resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_iso  29.310  0.065352  0.133803  1.892628  0.537771
# 4           densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_iso   7.650  0.016844  0.084918  0.277319  0.778261
# 6          densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_iso  30.220  0.052514  0.121643  1.649080  0.517046
# 8        resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_iso   5.010  0.010596  0.101016  0.234374  0.817886
# 10      resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_iso  24.090  0.053320  0.141408  1.533038  0.623213
# 12        resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_iso  29.308  0.073801  0.117242  2.994664  0.565222
# 14      densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_iso  27.264  0.072248  0.271487  2.931365  0.594190

# %%
df_beta = cal_results(BetaCalibration, PATH, files, {'parameters':"abm"})
# Out:
#  resnet110_c10
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
#
#  resnet110_c100
# Accuracy: 71.48
# Error: 28.52
# ECE: 0.184804543945
# MCE: 0.398817125148
# Loss: 1.69371210955
# brier: 0.661139586803
#
#  densenet40_c10
# Accuracy: 92.42
# Error: 7.58
# ECE: 0.055002704373
# MCE: 0.333955179269
# Loss: 0.42820705658
# brier: 0.819165176082
#
#  densenet40_c100
# Accuracy: 70.0
# Error: 30.0
# ECE: 0.211562852757
# MCE: 0.45400331452
# Loss: 2.0173981798
# brier: 0.655000941434
#
#  resnet_wide32_c10
# Accuracy: 94.99
# Error: 5.01
# ECE: 0.0262912020743
# MCE: 0.270675277616
# Loss: 0.18078037455
# brier: 0.837849477046
#
#  resnet_wide32_c100
# Accuracy: 77.2
# Error: 22.8
# ECE: 0.0824934380092
# MCE: 0.205758135969
# Loss: 0.924750990686
# brier: 0.679727633367
#
#  resnet152_imgnet
# Accuracy: 74.708
# Error: 25.292
# ECE: 0.0665072336364
# MCE: 0.133044166026
# Loss: 1.06397533857
# brier: 0.624490802257
#
#  densenet161_imgnet
# Accuracy: 76.6
# Error: 23.4
# ECE: 0.0589743148203
# MCE: 0.138486335666
# Loss: 0.962239300614
# brier: 0.645603191194

# %%
df_beta
# Out:
#                         Name   Error       ECE       MCE      Loss     Brier
# 0              resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_calib   6.440  0.014248  0.262211  0.213850  0.786434
# 2             resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_calib  28.360  0.046006  0.114420  1.131824  0.519578
# 4             densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_calib   7.590  0.017003  0.250324  0.239184  0.774672
# 6            densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_calib  29.810  0.060306  0.129234  1.153169  0.495494
# 8          resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_calib   5.000  0.009261  0.094009  0.154432  0.814365
# 10        resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_calib  22.930  0.048445  0.138961  0.889862  0.611984
# 12          resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_calib  25.260  0.033361  0.085628  1.061433  0.573767
# 14        densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_calib  23.276  0.033408  0.070665  0.999540  0.601961

# %%
df_beta_am = cal_results(BetaCalibration, PATH, files, {'parameters':"am"})
# Out:
#  resnet110_c10
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
#
#  resnet110_c100
# Accuracy: 71.48
# Error: 28.52
# ECE: 0.184804543945
# MCE: 0.398817125148
# Loss: 1.69371210955
# brier: 0.661139586803
#
#  densenet40_c10
# Accuracy: 92.42
# Error: 7.58
# ECE: 0.055002704373
# MCE: 0.333955179269
# Loss: 0.42820705658
# brier: 0.819165176082
#
#  densenet40_c100
# Accuracy: 70.0
# Error: 30.0
# ECE: 0.211562852757
# MCE: 0.45400331452
# Loss: 2.0173981798
# brier: 0.655000941434
#
#  resnet_wide32_c10
# Accuracy: 94.99
# Error: 5.01
# ECE: 0.0262912020743
# MCE: 0.270675277616
# Loss: 0.18078037455
# brier: 0.837849477046
#
#  resnet_wide32_c100
# Accuracy: 77.2
# Error: 22.8
# ECE: 0.0824934380092
# MCE: 0.205758135969
# Loss: 0.924750990686
# brier: 0.679727633367
#
#  resnet152_imgnet
# Accuracy: 74.708
# Error: 25.292
# ECE: 0.0665072336364
# MCE: 0.133044166026
# Loss: 1.06397533857
# brier: 0.624490802257
#
#  densenet161_imgnet
# Accuracy: 76.6
# Error: 23.4
# ECE: 0.0589743148203
# MCE: 0.138486335666
# Loss: 0.962239300614
# brier: 0.645603191194

# %%
df_beta_am
# Out:
#                         Name   Error       ECE       MCE      Loss     Brier
# 0              resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_calib   6.400  0.012823  0.250120  0.215255  0.789272
# 2             resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_calib  28.280  0.048011  0.120193  1.129195  0.534147
# 4             densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_calib   7.590  0.015536  0.146299  0.239227  0.778086
# 6            densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_calib  29.700  0.063341  0.143593  1.164765  0.522265
# 8          resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_calib   5.000  0.008012  0.081865  0.153624  0.814909
# 10        resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_calib  22.880  0.045709  0.126308  0.879483  0.627775
# 12          resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_calib  25.228  0.032255  0.078687  1.039389  0.581115
# 14        densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_calib  23.236  0.030084  0.111615  0.968818  0.608620

# %%
df_beta_ab = cal_results(BetaCalibration, PATH, files, {'parameters':"ab"})
# Out:
#  resnet110_c10
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
#
#  resnet110_c100
# Accuracy: 71.48
# Error: 28.52
# ECE: 0.184804543945
# MCE: 0.398817125148
# Loss: 1.69371210955
# brier: 0.661139586803
#
#  densenet40_c10
# Accuracy: 92.42
# Error: 7.58
# ECE: 0.055002704373
# MCE: 0.333955179269
# Loss: 0.42820705658
# brier: 0.819165176082
#
#  densenet40_c100
# Accuracy: 70.0
# Error: 30.0
# ECE: 0.211562852757
# MCE: 0.45400331452
# Loss: 2.0173981798
# brier: 0.655000941434
#
#  resnet_wide32_c10
# Accuracy: 94.99
# Error: 5.01
# ECE: 0.0262912020743
# MCE: 0.270675277616
# Loss: 0.18078037455
# brier: 0.837849477046
#
#  resnet_wide32_c100
# Accuracy: 77.2
# Error: 22.8
# ECE: 0.0824934380092
# MCE: 0.205758135969
# Loss: 0.924750990686
# brier: 0.679727633367
#
#  resnet152_imgnet
# Accuracy: 74.708
# Error: 25.292
# ECE: 0.0665072336364
# MCE: 0.133044166026
# Loss: 1.06397533857
# brier: 0.624490802257
#
#  densenet161_imgnet
# Accuracy: 76.6
# Error: 23.4
# ECE: 0.0589743148203
# MCE: 0.138486335666
# Loss: 0.962239300614
# brier: 0.645603191194

# %%
df_beta_ab
# Out:
#                         Name   Error       ECE       MCE      Loss     Brier
# 0              resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_calib   6.450  0.013754  0.244292  0.212043  0.788312
# 2             resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_calib  28.470  0.052776  0.127771  1.136727  0.551702
# 4             densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_calib   7.570  0.015656  0.105473  0.238213  0.776613
# 6            densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_calib  30.020  0.062958  0.106531  1.150210  0.521963
# 8          resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_calib   5.020  0.009303  0.146759  0.152603  0.815624
# 10        resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_calib  22.710  0.046272  0.138236  0.884919  0.622837
# 12          resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_calib  25.248  0.033241  0.069143  1.050777  0.579993
# 14        densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_calib  23.404  0.032046  0.066552  0.964951  0.603064

# %% [markdown]
# ## Histogram Binning

# %%
class HistogramBinning():
    
    
    def __init__(self, M=15):
        self.bin_size = 1./M  # Calculate bin size
        self.conf = []  # Initiate confidence list
        self.upper_bounds = np.arange(self.bin_size, 1+self.bin_size, self.bin_size)  # Set bin bounds for intervals

    
    def _get_conf(self, conf_thresh_lower, conf_thresh_upper, probs, true):

        filtered = [x[0] for x in zip(true, probs) if x[1] > conf_thresh_lower and x[1] <= conf_thresh_upper]
        nr_elems = len(filtered)

        if nr_elems < 1:
            return 0
        else:
            conf = sum(filtered)/nr_elems
            return conf
    

    def fit(self, probs, true):

        conf = []

        # Got through intervals and add confidence to list
        for conf_thresh in self.upper_bounds:
            temp_conf = self._get_conf((conf_thresh - self.bin_size), conf_thresh, probs = probs, true = true)
            conf.append(temp_conf)

        self.conf = conf

            


    # Fit based on predicted confidence
    def predict(self, probs):

        # Go through all the probs and check what confidence is suitable for it.
        for i, prob in enumerate(probs):
            idx = np.searchsorted(self.upper_bounds, prob)
            probs[i] = self.conf[idx]

        return probs

# %%
df_hb = cal_results(HistogramBinning, PATH, files, {'M':15})
# Out:
#  resnet110_c10
# Accuracy: 93.56
# Error: 6.44
# ECE: 0.047503518641
# MCE: 0.295798957348
# Loss: 0.358274134971
# brier: 0.831574102734
#
#  resnet110_c100
# Accuracy: 71.48
# Error: 28.52
# ECE: 0.184804543945
# MCE: 0.398817125148
# Loss: 1.69371210955
# brier: 0.661139586803
#
#  densenet40_c10
# Accuracy: 92.42
# Error: 7.58
# ECE: 0.055002704373
# MCE: 0.333955179269
# Loss: 0.42820705658
# brier: 0.819165176082
#
#  densenet40_c100
# Accuracy: 70.0
# Error: 30.0
# ECE: 0.211562852757
# MCE: 0.45400331452
# Loss: 2.0173981798
# brier: 0.655000941434
#
#  resnet_wide32_c10
# Accuracy: 94.99
# Error: 5.01
# ECE: 0.0262912020743
# MCE: 0.270675277616
# Loss: 0.18078037455
# brier: 0.837849477046
#
#  resnet_wide32_c100
# Accuracy: 77.2
# Error: 22.8
# ECE: 0.0824934380092
# MCE: 0.205758135969
# Loss: 0.924750990686
# brier: 0.679727633367
#
#  resnet152_imgnet
# Accuracy: 74.708
# Error: 25.292
# ECE: 0.0665072336364
# MCE: 0.133044166026
# Loss: 1.06397533857
# brier: 0.624490802257
#
#  densenet161_imgnet
# Accuracy: 76.6
# Error: 23.4
# ECE: 0.0589743148203
# MCE: 0.138486335666
# Loss: 0.962239300614
# brier: 0.645603191194

# %%
df_hb
# Out:
#                         Name   Error       ECE       MCE      Loss     Brier
# 0              resnet110_c10   6.440  0.047504  0.295799  0.358274  0.831574
# 1        resnet110_c10_calib   6.590  0.012508  0.444502  0.547192  0.779163
# 2             resnet110_c100  28.520  0.184805  0.398817  1.693712  0.661140
# 3       resnet110_c100_calib  31.260  0.090558  0.316352  4.213913  0.510992
# 4             densenet40_c10   7.580  0.055003  0.333955  0.428207  0.819165
# 5       densenet40_c10_calib   7.930  0.021302  0.451015  0.572461  0.763132
# 6            densenet40_c100  30.000  0.211563  0.454003  2.017398  0.655001
# 7      densenet40_c100_calib  32.490  0.119705  0.169395  4.182849  0.471067
# 8          resnet_wide32_c10   5.010  0.026291  0.270675  0.180780  0.837849
# 9    resnet_wide32_c10_calib   5.310  0.014299  0.266247  0.544360  0.816282
# 10        resnet_wide32_c100  22.800  0.082493  0.205758  0.924751  0.679728
# 11  resnet_wide32_c100_calib  26.640  0.094278  0.280764  4.078534  0.613907
# 12          resnet152_imgnet  25.292  0.066507  0.133044  1.063975  0.624491
# 13    resnet152_imgnet_calib  33.296  0.087110  0.278709  6.525190  0.565937
# 14        densenet161_imgnet  23.400  0.058974  0.138486  0.962239  0.645603
# 15  densenet161_imgnet_calib  31.092  0.087912  0.290375  6.283186  0.593834

# %% [markdown]
# ## Dirilecht Calibration

# %%
class DirilechCalibration():
    
    def __init__(self, parameters)

# %% [markdown]
# ## Dataframe of results

# %%
# df_temp_scale, df_iso, df_beta, df_hb

dfs = [df_hb, df_iso, df_temp_scale, df_beta, df_beta_am, df_beta_ab]
names = ["Name", "Uncalibrated", "Histogram Binning", "Isotonic Regression", "Temperature Scaling", "Beta Calibration",
        "BC am", "BC ab"]


def get_dataframe(dfs, column, names):

    df_res = pd.DataFrame(columns=names)

    for i in range(1, len(df_iso), 2):

        name = dfs[0].iloc[i-1]["Name"] # Get name of method
        uncalibrated = dfs[0].iloc[i-1][column]  # Get uncalibrated score

        row = [name, uncalibrated]  # Add scores to row

        for df in dfs:
            row.append(df.iloc[i][column])

        df_res.loc[(i-1)//2] = row
        #errordf.iloc[i]
    
    df_res.set_index('Name', inplace = True)
        
    return df_res

# %%
df_error = get_dataframe(dfs, "Error", names)
df_ece = get_dataframe(dfs, "ECE", names)
df_mce = get_dataframe(dfs, "MCE", names)
df_loss = get_dataframe(dfs, "Loss", names)
df_brier = get_dataframe(dfs, "Brier", names)

# %% [markdown]
# ## Scores

# %%
def highlight_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.min()
    return ['background-color: yellow' if v else '' for v in is_max]

# %% [markdown]
# ## Error

# %%
df_error.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col2 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col5 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col6 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col5 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col4 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col5 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col6 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col5 {
#             background-color:  yellow;
#         }    #T_035131d0_390a_11e8_80db_a08cfd9dff3crow7_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Histogram Binning</th>
#         <th class="col_heading level0 col2" >Isotonic Regression</th>
#         <th class="col_heading level0 col3" >Temperature Scaling</th>
#         <th class="col_heading level0 col4" >Beta Calibration</th>
#         <th class="col_heading level0 col5" >BC am</th>
#         <th class="col_heading level0 col6" >BC ab</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row0" >resnet110_c10</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col0" class="data row0 col0" >6.44</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col1" class="data row0 col1" >6.59</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col2" class="data row0 col2" >6.36</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col3" class="data row0 col3" >6.44</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col4" class="data row0 col4" >6.44</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col5" class="data row0 col5" >6.4</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow0_col6" class="data row0 col6" >6.45</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row1" >resnet110_c100</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col0" class="data row1 col0" >28.52</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col1" class="data row1 col1" >31.26</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col2" class="data row1 col2" >29.31</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col3" class="data row1 col3" >28.52</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col4" class="data row1 col4" >28.36</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col5" class="data row1 col5" >28.28</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow1_col6" class="data row1 col6" >28.47</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row2" >densenet40_c10</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col0" class="data row2 col0" >7.58</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col1" class="data row2 col1" >7.93</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col2" class="data row2 col2" >7.65</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col3" class="data row2 col3" >7.58</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col4" class="data row2 col4" >7.59</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col5" class="data row2 col5" >7.59</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow2_col6" class="data row2 col6" >7.57</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row3" >densenet40_c100</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col0" class="data row3 col0" >30</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col1" class="data row3 col1" >32.49</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col2" class="data row3 col2" >30.22</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col3" class="data row3 col3" >30</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col4" class="data row3 col4" >29.81</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col5" class="data row3 col5" >29.7</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow3_col6" class="data row3 col6" >30.02</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row4" >resnet_wide32_c10</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col0" class="data row4 col0" >5.01</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col1" class="data row4 col1" >5.31</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col2" class="data row4 col2" >5.01</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col3" class="data row4 col3" >5.01</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col4" class="data row4 col4" >5</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col5" class="data row4 col5" >5</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow4_col6" class="data row4 col6" >5.02</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row5" >resnet_wide32_c100</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col0" class="data row5 col0" >22.8</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col1" class="data row5 col1" >26.64</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col2" class="data row5 col2" >24.09</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col3" class="data row5 col3" >22.8</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col4" class="data row5 col4" >22.93</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col5" class="data row5 col5" >22.88</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow5_col6" class="data row5 col6" >22.71</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row6" >resnet152_imgnet</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col0" class="data row6 col0" >25.292</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col1" class="data row6 col1" >33.296</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col2" class="data row6 col2" >29.308</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col3" class="data row6 col3" >25.292</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col4" class="data row6 col4" >25.26</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col5" class="data row6 col5" >25.228</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow6_col6" class="data row6 col6" >25.248</td>
#     </tr>    <tr>
#         <th id="T_035131d0_390a_11e8_80db_a08cfd9dff3c" class="row_heading level0 row7" >densenet161_imgnet</th>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow7_col0" class="data row7 col0" >23.4</td>
#         <td id="T_035131d0_390a_11e8_80db_a08cfd9dff3crow7_col1" class="data row

# %% [markdown]
# ## ECE

# %%
df_ece.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col3 {
#             background-color:  yellow;
#         }    #T_03572a1e_390a_11e8_8928_a08cfd9dff3crow7_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Histogram Binning</th>
#         <th class="col_heading level0 col2" >Isotonic Regression</th>
#         <th class="col_heading level0 col3" >Temperature Scaling</th>
#         <th class="col_heading level0 col4" >Beta Calibration</th>
#         <th class="col_heading level0 col5" >BC am</th>
#         <th class="col_heading level0 col6" >BC ab</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row0" >resnet110_c10</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col0" class="data row0 col0" >0.0475035</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col1" class="data row0 col1" >0.0125078</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col2" class="data row0 col2" >0.0147359</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col3" class="data row0 col3" >0.0113208</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col4" class="data row0 col4" >0.0142481</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col5" class="data row0 col5" >0.0128235</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow0_col6" class="data row0 col6" >0.0137544</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row1" >resnet110_c100</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col0" class="data row1 col0" >0.184805</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col1" class="data row1 col1" >0.0905575</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col2" class="data row1 col2" >0.0653516</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col3" class="data row1 col3" >0.0237971</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col4" class="data row1 col4" >0.0460063</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col5" class="data row1 col5" >0.0480109</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow1_col6" class="data row1 col6" >0.0527756</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row2" >densenet40_c10</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col0" class="data row2 col0" >0.0550027</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col1" class="data row2 col1" >0.021302</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col2" class="data row2 col2" >0.0168437</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col3" class="data row2 col3" >0.00946355</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col4" class="data row2 col4" >0.0170027</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col5" class="data row2 col5" >0.0155363</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow2_col6" class="data row2 col6" >0.0156559</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row3" >densenet40_c100</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col0" class="data row3 col0" >0.211563</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col1" class="data row3 col1" >0.119705</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col2" class="data row3 col2" >0.0525144</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col3" class="data row3 col3" >0.00902072</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col4" class="data row3 col4" >0.0603064</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col5" class="data row3 col5" >0.0633407</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow3_col6" class="data row3 col6" >0.062958</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row4" >resnet_wide32_c10</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col0" class="data row4 col0" >0.0262912</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col1" class="data row4 col1" >0.0142993</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col2" class="data row4 col2" >0.010596</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col3" class="data row4 col3" >0.00796326</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col4" class="data row4 col4" >0.00926128</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col5" class="data row4 col5" >0.00801195</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow4_col6" class="data row4 col6" >0.0093031</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row5" >resnet_wide32_c100</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col0" class="data row5 col0" >0.0824934</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col1" class="data row5 col1" >0.0942779</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col2" class="data row5 col2" >0.0533204</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col3" class="data row5 col3" >0.0422688</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col4" class="data row5 col4" >0.0484455</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col5" class="data row5 col5" >0.0457086</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow5_col6" class="data row5 col6" >0.0462717</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row6" >resnet152_imgnet</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col0" class="data row6 col0" >0.0665072</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col1" class="data row6 col1" >0.0871103</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col2" class="data row6 col2" >0.0738013</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col3" class="data row6 col3" >0.0222174</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col4" class="data row6 col4" >0.0333611</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col5" class="data row6 col5" >0.0322548</td>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow6_col6" class="data row6 col6" >0.0332408</td>
#     </tr>    <tr>
#         <th id="T_03572a1e_390a_11e8_8928_a08cfd9dff3c" class="row_heading level0 row7" >densenet161_imgnet</th>
#         <td id="T_03572a1e_390a_11e8_8928_a08cfd9dff3crow

# %% [markdown]
# ## MCE

# %%
df_mce.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col3 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col3 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col2 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col3 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col5 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col3 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col3 {
#             background-color:  yellow;
#         }    #T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow7_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Histogram Binning</th>
#         <th class="col_heading level0 col2" >Isotonic Regression</th>
#         <th class="col_heading level0 col3" >Temperature Scaling</th>
#         <th class="col_heading level0 col4" >Beta Calibration</th>
#         <th class="col_heading level0 col5" >BC am</th>
#         <th class="col_heading level0 col6" >BC ab</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row0" >resnet110_c10</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col0" class="data row0 col0" >0.295799</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col1" class="data row0 col1" >0.444502</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col2" class="data row0 col2" >0.245814</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col3" class="data row0 col3" >0.236393</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col4" class="data row0 col4" >0.262211</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col5" class="data row0 col5" >0.25012</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow0_col6" class="data row0 col6" >0.244292</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row1" >resnet110_c100</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col0" class="data row1 col0" >0.398817</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col1" class="data row1 col1" >0.316352</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col2" class="data row1 col2" >0.133803</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col3" class="data row1 col3" >0.0709914</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col4" class="data row1 col4" >0.11442</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col5" class="data row1 col5" >0.120193</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow1_col6" class="data row1 col6" >0.127771</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row2" >densenet40_c10</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col0" class="data row2 col0" >0.333955</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col1" class="data row2 col1" >0.451015</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col2" class="data row2 col2" >0.0849184</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col3" class="data row2 col3" >0.0992925</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col4" class="data row2 col4" >0.250324</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col5" class="data row2 col5" >0.146299</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow2_col6" class="data row2 col6" >0.105473</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row3" >densenet40_c100</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col0" class="data row3 col0" >0.454003</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col1" class="data row3 col1" >0.169395</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col2" class="data row3 col2" >0.121643</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col3" class="data row3 col3" >0.0221282</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col4" class="data row3 col4" >0.129234</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col5" class="data row3 col5" >0.143593</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow3_col6" class="data row3 col6" >0.106531</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row4" >resnet_wide32_c10</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col0" class="data row4 col0" >0.270675</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col1" class="data row4 col1" >0.266247</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col2" class="data row4 col2" >0.101016</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col3" class="data row4 col3" >0.254111</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col4" class="data row4 col4" >0.0940089</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col5" class="data row4 col5" >0.0818646</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow4_col6" class="data row4 col6" >0.146759</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row5" >resnet_wide32_c100</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col0" class="data row5 col0" >0.205758</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col1" class="data row5 col1" >0.280764</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col2" class="data row5 col2" >0.141408</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col3" class="data row5 col3" >0.108004</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col4" class="data row5 col4" >0.138961</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col5" class="data row5 col5" >0.126308</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow5_col6" class="data row5 col6" >0.138236</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row6" >resnet152_imgnet</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col0" class="data row6 col0" >0.133044</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col1" class="data row6 col1" >0.278709</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col2" class="data row6 col2" >0.117242</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col3" class="data row6 col3" >0.0605335</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col4" class="data row6 col4" >0.0856277</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col5" class="data row6 col5" >0.0786869</td>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow6_col6" class="data row6 col6" >0.0691434</td>
#     </tr>    <tr>
#         <th id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3c" class="row_heading level0 row7" >densenet161_imgnet</th>
#         <td id="T_035b9a2c_390a_11e8_8699_a08cfd9dff3crow7_col0" class="data row7 col0" >0.138486

# %% [markdown]
# ## Loss

# %%
df_loss.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col6 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col3 {
#             background-color:  yellow;
#         }    #T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow7_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Histogram Binning</th>
#         <th class="col_heading level0 col2" >Isotonic Regression</th>
#         <th class="col_heading level0 col3" >Temperature Scaling</th>
#         <th class="col_heading level0 col4" >Beta Calibration</th>
#         <th class="col_heading level0 col5" >BC am</th>
#         <th class="col_heading level0 col6" >BC ab</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row0" >resnet110_c10</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col0" class="data row0 col0" >0.358274</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col1" class="data row0 col1" >0.547192</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col2" class="data row0 col2" >0.270758</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col3" class="data row0 col3" >0.209261</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col4" class="data row0 col4" >0.21385</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col5" class="data row0 col5" >0.215255</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow0_col6" class="data row0 col6" >0.212043</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row1" >resnet110_c100</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col0" class="data row1 col0" >1.69371</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col1" class="data row1 col1" >4.21391</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col2" class="data row1 col2" >1.89263</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col3" class="data row1 col3" >1.09169</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col4" class="data row1 col4" >1.13182</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col5" class="data row1 col5" >1.12919</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow1_col6" class="data row1 col6" >1.13673</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row2" >densenet40_c10</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col0" class="data row2 col0" >0.428207</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col1" class="data row2 col1" >0.572461</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col2" class="data row2 col2" >0.277319</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col3" class="data row2 col3" >0.225086</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col4" class="data row2 col4" >0.239184</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col5" class="data row2 col5" >0.239227</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow2_col6" class="data row2 col6" >0.238213</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row3" >densenet40_c100</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col0" class="data row3 col0" >2.0174</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col1" class="data row3 col1" >4.18285</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col2" class="data row3 col2" >1.64908</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col3" class="data row3 col3" >1.05713</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col4" class="data row3 col4" >1.15317</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col5" class="data row3 col5" >1.16477</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow3_col6" class="data row3 col6" >1.15021</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row4" >resnet_wide32_c10</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col0" class="data row4 col0" >0.18078</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col1" class="data row4 col1" >0.54436</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col2" class="data row4 col2" >0.234374</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col3" class="data row4 col3" >0.154391</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col4" class="data row4 col4" >0.154432</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col5" class="data row4 col5" >0.153624</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow4_col6" class="data row4 col6" >0.152603</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row5" >resnet_wide32_c100</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col0" class="data row5 col0" >0.924751</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col1" class="data row5 col1" >4.07853</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col2" class="data row5 col2" >1.53304</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col3" class="data row5 col3" >0.871434</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col4" class="data row5 col4" >0.889862</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col5" class="data row5 col5" >0.879483</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow5_col6" class="data row5 col6" >0.884919</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row6" >resnet152_imgnet</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col0" class="data row6 col0" >1.06398</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col1" class="data row6 col1" >6.52519</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col2" class="data row6 col2" >2.99466</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col3" class="data row6 col3" >1.01687</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col4" class="data row6 col4" >1.06143</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col5" class="data row6 col5" >1.03939</td>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow6_col6" class="data row6 col6" >1.05078</td>
#     </tr>    <tr>
#         <th id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3c" class="row_heading level0 row7" >densenet161_imgnet</th>
#         <td id="T_03611af8_390a_11e8_bbbf_a08cfd9dff3crow7_col0" class="data row7 col0" >0.962239</td>
#         <td id="T_03611af8_3

# %% [markdown]
# ## Brier

# %%
df_brier.style.apply(highlight_min, axis = 1)
# Out:
# <style  type="text/css" >
#     #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col1 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col1 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col1 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col1 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col4 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col4 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col2 {
#             background-color:  yellow;
#         }    #T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow7_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Uncalibrated</th>
#         <th class="col_heading level0 col1" >Histogram Binning</th>
#         <th class="col_heading level0 col2" >Isotonic Regression</th>
#         <th class="col_heading level0 col3" >Temperature Scaling</th>
#         <th class="col_heading level0 col4" >Beta Calibration</th>
#         <th class="col_heading level0 col5" >BC am</th>
#         <th class="col_heading level0 col6" >BC ab</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row0" >resnet110_c10</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col0" class="data row0 col0" >0.831574</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col1" class="data row0 col1" >0.779163</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col2" class="data row0 col2" >0.790379</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col3" class="data row0 col3" >0.788059</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col4" class="data row0 col4" >0.786434</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col5" class="data row0 col5" >0.789272</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow0_col6" class="data row0 col6" >0.788312</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row1" >resnet110_c100</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col0" class="data row1 col0" >0.66114</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col1" class="data row1 col1" >0.510992</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col2" class="data row1 col2" >0.537771</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col3" class="data row1 col3" >0.524876</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col4" class="data row1 col4" >0.519578</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col5" class="data row1 col5" >0.534147</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow1_col6" class="data row1 col6" >0.551702</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row2" >densenet40_c10</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col0" class="data row2 col0" >0.819165</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col1" class="data row2 col1" >0.763132</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col2" class="data row2 col2" >0.778261</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col3" class="data row2 col3" >0.770248</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col4" class="data row2 col4" >0.774672</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col5" class="data row2 col5" >0.778086</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow2_col6" class="data row2 col6" >0.776613</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row3" >densenet40_c100</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col0" class="data row3 col0" >0.655001</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col1" class="data row3 col1" >0.471067</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col2" class="data row3 col2" >0.517046</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col3" class="data row3 col3" >0.491403</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col4" class="data row3 col4" >0.495494</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col5" class="data row3 col5" >0.522265</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow3_col6" class="data row3 col6" >0.521963</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row4" >resnet_wide32_c10</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col0" class="data row4 col0" >0.837849</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col1" class="data row4 col1" >0.816282</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col2" class="data row4 col2" >0.817886</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col3" class="data row4 col3" >0.814687</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col4" class="data row4 col4" >0.814365</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col5" class="data row4 col5" >0.814909</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow4_col6" class="data row4 col6" >0.815624</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row5" >resnet_wide32_c100</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col0" class="data row5 col0" >0.679728</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col1" class="data row5 col1" >0.613907</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col2" class="data row5 col2" >0.623213</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col3" class="data row5 col3" >0.63246</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col4" class="data row5 col4" >0.611984</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col5" class="data row5 col5" >0.627775</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow5_col6" class="data row5 col6" >0.622837</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row6" >resnet152_imgnet</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col0" class="data row6 col0" >0.624491</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col1" class="data row6 col1" >0.565937</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col2" class="data row6 col2" >0.565222</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col3" class="data row6 col3" >0.571829</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col4" class="data row6 col4" >0.573767</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col5" class="data row6 col5" >0.581115</td>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow6_col6" class="data row6 col6" >0.579993</td>
#     </tr>    <tr>
#         <th id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3c" class="row_heading level0 row7" >densenet161_imgnet</th>
#         <td id="T_0367881c_390a_11e8_8ef8_a08cfd9dff3crow7_col0" class="data row7 col0" >0.645603</td>
